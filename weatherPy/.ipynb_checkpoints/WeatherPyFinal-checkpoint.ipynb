# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keysCopy1 import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['upernavik',
#  'ushuaia',
#  'punta arenas',
#  'puerto ayora',
#  'lompoc',
#  'leningradskiy',
#  'inhambane',
#  'yuzhno-sukhokumsk',
#  'cabo san lucas',
#  'rikitea',
#  'peterhead',
#  'dongsheng',
#  'mataura',
#  'atuona',
#  'lebu',
#  'vaini',
#  'taolanaro',
#  'genhe',
#  'broome',
#  'port alfred',
#  'barsovo',
#  'torbay',
#  'illoqqortoormiut',
#  'arraial do cabo',
#  'ostrovnoy',
#  'abu samrah',
#  'mataram',
#  'yatou',
#  'khatanga',
#  'emporia',
#  'guerrero negro',
#  'coahuayana',
#  'vagay',
#  'saskylakh',
#  'del rio',
#  'bredasdorp',
#  'nizhneyansk',
#  'ribeira grande',
#  'arys',
#  'bengkulu',
#  'pisco',
#  'esperance',
#  'lavumisa',
#  'barrow',
#  'bluff',
#  'walvis bay',
#  'codrington',
#  'villa maria',
#  'jamestown',
#  'kapaa',
#  'uglovka',
#  'grojec',
#  'avarua',
#  'bin qirdan',
#  'saint anthony',
#  'bethel',
#  'seydisehir',
#  'aasiaat',
#  'bintulu',
#  'ugoofaaru',
#  'andros town',
#  'skibbereen',
#  'hobart',
#  'castro',
#  'fort nelson',
#  'emba',
#  'marysville',
#  'meulaboh',
#  'attawapiskat',
#  'ye',
#  'chuy',
#  'ponta do sol',
#  'busselton',
#  'provideniya',
#  'palmi',
#  'amparafaravola',
#  'cape town',
#  'bathsheba',
#  'tiksi',
#  'tecoanapa',
#  'butaritari',
#  'whitehorse',
#  'nouadhibou',
#  'moses lake',
#  'amderma',
#  'acajutla',
#  'lavrentiya',
#  'ancud',
#  'hammerfest',
#  'yellowknife',
#  'tautira',
#  'kavieng',
#  'bambous virieux',
#  'sentyabrskiy',
#  'raga',
#  'nantucket',
#  'atchison',
#  'pevek',
#  'nikolskoye',
#  'pathein',
#  'ambulu',
#  'cockburn town',
#  'saint-joseph',
#  'doha',
#  'airai',
#  'yulara',
#  'urfa',
#  'mpongwe',
#  'thunder bay',
#  'aswan',
#  'saraland',
#  'albany',
#  'salalah',
#  'tuktoyaktuk',
#  'hithadhoo',
#  'ust-omchug',
#  'qaanaaq',
#  'nyurba',
#  'yokadouma',
#  'sao filipe',
#  'wucheng',
#  'auki',
#  'grand river south east',
#  'liminangcong',
#  'prince rupert',
#  'weihai',
#  'kaili',
#  'saint george',
#  'dikson',
#  'victoria',
#  'hermanus',
#  'ishigaki',
#  'sobradinho',
#  'new norfolk',
#  'olinda',
#  'bilibino',
#  'tasiilaq',
#  'dmanisi',
#  'timizart',
#  'norman wells',
#  'vaitupu',
#  'carnarvon',
#  'santa lucia',
#  'keti bandar',
#  'husavik',
#  'mar del plata',
#  'yangambi',
#  'arman',
#  'porto murtinho',
#  'severo-kurilsk',
#  'faanui',
#  'nuuk',
#  'longyearbyen',
#  'belaya gora',
#  'upington',
#  'mahebourg',
#  'iqaluit',
#  'atar',
#  'fairbanks',
#  'kaitangata',
#  'impfondo',
#  'pangnirtung',
#  'sayyan',
#  'arlit',
#  'vilyuysk',
#  'fortuna',
#  'east london',
#  'bolshiye uki',
#  'aripuana',
#  'abeche',
#  'marcona',
#  'port lincoln',
#  'goundam',
#  'rio gallegos',
#  'quito',
#  'sarahan',
#  'chimbote',
#  'georgetown',
#  'yarada',
#  'kargil',
#  'severo-yeniseyskiy',
#  'laviana',
#  'wajima',
#  'kruisfontein',
#  'socorro',
#  'college',
#  'siuna',
#  'jyvaskyla',
#  'ossora',
#  'espinosa',
#  'san quintin',
#  'krasnyy oktyabr',
#  'belushya guba',
#  'mys shmidta',
#  'tsihombe',
#  'chinsali',
#  'kahului',
#  'lolua',
#  'hastings',
#  'san matias',
#  'bilma',
#  'jahrom',
#  'kapit',
#  'muisne',
#  'jaque',
#  'cherskiy',
#  'nemuro',
#  'thompson',
#  'north bend',
#  'challans',
#  'terrell',
#  'quelimane',
#  'azangaro',
#  'fushan',
#  'mount isa',
#  'hokitika',
#  'rocha',
#  'hagerstown',
#  'amapa',
#  'campbell river',
#  'hilo',
#  'kodiak',
#  'quatre cocos',
#  'nelson bay',
#  'christchurch',
#  'asau',
#  'grindavik',
#  'vanavara',
#  'borogontsy',
#  'narsingdi',
#  'igrim',
#  'parbatipur',
#  'bubaque',
#  'marawi',
#  'peniche',
#  'kaoma',
#  'kachug',
#  'tazovskiy',
#  'waipawa',
#  'sinjai',
#  'turukhansk',
#  'san salvo',
#  'ust-ilimsk',
#  'wamba',
#  'gornopravdinsk',
#  'dingle',
#  'medicine hat',
#  'watertown',
#  'morgan city',
#  'lorengau',
#  'bafq',
#  'hovd',
#  'syracuse',
#  'udachnyy',
#  'komsomolskiy',
#  'richards bay',
#  'pestretsy',
#  'cap malheureux',
#  'kualakapuas',
#  'padang',
#  'balikpapan',
#  'coquimbo',
#  'naze',
#  'lakota',
#  'mizan teferi',
#  'zinder',
#  'puri',
#  'qasigiannguit',
#  'santa isabel do rio negro',
#  'kununurra',
#  'dekoa',
#  'fierze',
#  'toliary',
#  'saleaula',
#  'lazaro cardenas',
#  'pachino',
#  'aliaga',
#  'kieta',
#  'kamaishi',
#  'berlevag',
#  'kitob',
#  'bakchar',
#  'cidreira',
#  'saint-augustin',
#  'san carlos de bariloche',
#  'westport',
#  'natal',
#  'aklavik',
#  'akureyri',
#  'muros',
#  'gizo',
#  'kloulklubed',
#  'cabedelo',
#  'la ronge',
#  'mingshui',
#  'flinders',
#  'tupik',
#  'rio grande',
#  'xuddur',
#  'bagdarin',
#  'vila franca do campo',
#  'vostok',
#  'paamiut',
#  'krasnoborsk',
#  'bria',
#  'vila velha',
#  'oksfjord',
#  'bafata',
#  'camacha',
#  'dancheng',
#  'anadyr',
#  'phan rang',
#  'kibiti',
#  'saldanha',
#  'longjiang',
#  'were ilu',
#  'kenai',
#  'beloha',
#  'lieksa',
#  'ilulissat',
#  'mazatlan',
#  'rabo de peixe',
#  'barentsburg',
#  'portland',
#  'tuatapere',
#  'taoudenni',
#  'biak',
#  'kriel',
#  'sataua',
#  'havre-saint-pierre',
#  'sur',
#  'siderno',
#  'marrakesh',
#  'qostanay',
#  'xining',
#  'kiama',
#  'codajas',
#  'yar-sale',
#  'lewiston',
#  'coronon',
#  'den helder',
#  'san cristobal',
#  'ostrov',
#  'kifri',
#  'pangoa',
#  'fare',
#  'elat',
#  'south yuba city',
#  'aketi',
#  'khotkovo',
#  'coihaique',
#  'palmer',
#  'pishin',
#  'krasnoselkup',
#  'karaul',
#  'sitka',
#  'roma',
#  'salinas',
#  'saint-philippe',
#  'santa fe',
#  'puksoozero',
#  'luderitz',
#  'mogadishu',
#  'falmouth',
#  'miri',
#  'suntar',
#  'centralia',
#  'dzhusaly',
#  'sola',
#  'son la',
#  'liverpool',
#  'tura',
#  'taneatua',
#  'zhigansk',
#  'poya',
#  'half moon bay',
#  'hirara',
#  'asuncion',
#  'atherton',
#  'miramar',
#  'valladolid',
#  'rawannawi',
#  'chegdomyn',
#  'san patricio',
#  'tomatlan',
#  'leh',
#  'talnakh',
#  'mersing',
#  'chernyshevskiy',
#  'san andres',
#  'teguise',
#  'sakaiminato',
#  'grootfontein',
#  'ahipara',
#  'adrar',
#  'phaphund',
#  'necochea',
#  'illapel',
#  'smithers',
#  'mitsamiouli',
#  'tulun',
#  'te anau',
#  'umm lajj',
#  'umm kaddadah',
#  'hasaki',
#  'kollo',
#  'kysyl-syr',
#  'kavaratti',
#  'ixtapa',
#  'rakai',
#  'hami',
#  'dudinka',
#  'karamea',
#  'novita',
#  'clyde river',
#  'marsh harbour',
#  'altay',
#  'gold coast',
#  'qingyuan',
#  'vestmanna',
#  'ust-kuyga',
#  'swellendam',
#  'banda aceh',
#  'port augusta',
#  'hofn',
#  'souillac',
#  'gat',
#  'faya',
#  'olafsvik',
#  'antofagasta',
#  'changji',
#  'broken hill',
#  'alice springs',
#  'parintins',
#  'lipin bor',
#  'erzin',
#  'ruatoria',
#  'chuguyevka',
#  'auburn',
#  'lerwick',
#  'pauini',
#  'napierville',
#  'buchanan',
#  'kirakira',
#  'palauig',
#  'constitucion',
#  'bajil',
#  'whitianga',
#  'katobu',
#  'kilimatinde',
#  'dianopolis',
#  'aki',
#  'nguiu',
#  'manzanillo',
#  'bayonne',
#  'el faiyum',
#  'aranos',
#  'kurumkan',
#  'polson',
#  'eureka',
#  'acapulco',
#  'sungurlu',
#  'alghero',
#  'seoul',
#  'nome',
#  'warri',
#  'sisimiut',
#  'ashti',
#  'ambovombe',
#  'soyo',
#  'winslow',
#  'douentza',
#  'puerto suarez',
#  'riyadh',
#  'kulhudhuffushi',
#  'caravelas',
#  'cururupu',
#  'hegang',
#  'norsup',
#  'jabinyanah',
#  'lokosovo',
#  'kasimbazar',
#  'kendari',
#  'asahi',
#  'shakawe',
#  'loa janan',
#  'huntsville',
#  'port hardy',
#  'novodugino',
#  'nishihara',
#  'bowen',
#  'arawa',
#  'saint-pierre',
#  'shubarshi',
#  'buariki',
#  'luyang',
#  'kimbe',
#  'port elizabeth',
#  'catamarca',
#  'hambantota',
#  'thiers',
#  'laguna',
#  'nanortalik',
#  'isangel',
#  'ust-barguzin',
#  'guarapari',
#  'katsuura',
#  'phan thiet',
#  'macon',
#  'muroto',
#  'narsaq',
#  'maniitsoq',
#  'lima',
#  'agadir',
#  'vanimo',
#  'borama',
#  'jining',
#  'kasongo-lunda',
#  'okitipupa',
#  'dryden',
#  'kjollefjord',
#  'vardo',
#  'marathon',
#  'xuanhua',
#  'virginia beach',
#  'qiongshan',
#  'nisia floresta',
#  'warqla',
#  'namatanai',
#  'mayumba',
#  'lata',
#  'omboue',
#  'gorno-chuyskiy',
#  'general roca',
#  'barcelos',
#  'talas',
#  'rungata',
#  'rundu',
#  'ipixuna',
#  'meadow lake',
#  'presidente epitacio',
#  'krasnogvardeyskiy',
#  'kailua',
#  'yaan',
#  'cortez',
#  'harper',
#  'tyazhinskiy',
#  'sao felix do xingu',
#  'de-kastri',
#  'perambalur',
#  'prainha',
#  'hassleholm',
#  'progress',
#  'beringovskiy',
#  'sumbe',
#  'sheregesh',
#  'nalut',
#  'bandarbeyla',
#  'kampong thum',
#  'dunedin',
#  'gemena',
#  'rabat',
#  'cahors',
#  'lasa',
#  'grand centre',
#  'pacific grove',
#  'jiangyou',
#  'uglegorsk',
#  'crown point',
#  'presidencia roque saenz pena',
#  'artyom',
#  'rapid valley',
#  'nagykanizsa',
#  'ridgecrest',
#  'zhaocheng',
#  'lagoa',
#  'bokspits',
#  'benalla',
#  'weligama',
#  'touros',
#  'lakhdenpokhya',
#  'san rafael',
#  'ngunguru',
#  'novyy yarychiv',
#  'mount darwin',
#  'gamba',
#  'dehloran',
#  'santa rosa',
#  'gueret',
#  'robertsport',
#  'mossendjo']

# %%
#Perform a weather check on each city using a series of successive API calls
#Include a print log of each city as its being processed
lat = []
citynames = []
lng = []
maxtemp = []
humidity = []
cloudiness = []
windspeed = []
country = []
date = []
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
print('Beginning Data Retrieval')
print('------------------------------')
for city in cities:
    response = requests.get(query_url + city).json()
    try:
        cityname = response['name']
        citynames.append(response['name'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        maxtemp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        windspeed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
    except KeyError:
        print('City not found. Skipping...')
    index = cities.index(city) + 1
    setnumber = np.floor(1 + (index/50))
    if setnumber > 1:
        index = index - (setnumber - 1) * 50
   

    #print(f'Processing Record {index} of Set {setnumber} | {city}')
    
#response = requests.get(query_url + cities[0]).json()
#print(json.dumps(response, indent= 4, sort_keys=True))
# Out:
# Beginning Data Retrieval
# ------------------------------
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...

# %%
len(date)
# Out:
# 548

# %%
weather_df = pd.DataFrame({
    'City' : citynames,
    'Latitude' : lat,
    'Longitude' : lng,
    'Max Temperature (F)' : maxtemp,
    'Humidity' : humidity,
    'Cloudiness' : cloudiness,
    'Wind Speed' : windspeed,
    'County' : country,
    'Date' : date
})
weather_df.head()
# Out:
#            City  Latitude  Longitude  Max Temperature (F)  Humidity  \
# 0     Upernavik   72.7868   -56.1549                -6.61        74
# 1       Ushuaia  -54.8000   -68.3000                 7.81        71
# 2  Punta Arenas  -53.1500   -70.9167                10.06        66
# 3  Puerto Ayora   -0.7393   -90.3518                24.98        94
# 4        Lompoc   34.6391  -120.4579                34.27        56
#
#    Cloudiness  Wind Speed County        Date
# 0          14        2.30     GL  1652554826
# 1          20        2.57     AR  1652555183
# 2          20        9.26     CL  1652555167
# 3          78        1.34     EC  1652555191
# 4           0        8.75     US  1652554938

# %%
weather_df.to_csv('weather_data_cities.csv', encoding = 'utf-8', index = False)

# %%
weather_df.describe()
# Out:
#          Latitude   Longitude  Max Temperature (F)    Humidity  Cloudiness  \
# count  548.000000  548.000000           548.000000  548.000000  548.000000
# mean    20.764961   18.533824            18.168704   69.264599   58.417883
# std     33.421868   91.033574            10.206309   22.879968   40.813602
# min    -54.800000 -175.200000           -15.300000    3.000000    0.000000
# 25%     -5.910275  -60.487425            11.075000   57.000000   14.750000
# 50%     25.826100   21.061850            19.475000   74.000000   75.000000
# 75%     47.673350  102.269050            26.335000   86.000000  100.000000
# max     78.218600  179.316700            38.980000  100.000000  100.000000
#
#        Wind Speed          Date
# count  548.000000  5.480000e+02
# mean     3.452336  1.652555e+09
# std      2.412421  9.745345e+01
# min      0.000000  1.652555e+09
# 25%      1.687500  1.652555e+09
# 50%      2.765000  1.652555e+09
# 75%      4.785000  1.652555e+09
# max     14.050000  1.652555e+09

# %%
weather_df.loc[(weather_df['Humidity'] > 100), :].head()
#no cities with humidity greater than 100%
# Out:
# Empty DataFrame
# Columns: [City, Latitude, Longitude, Max Temperature (F), Humidity, Cloudiness, Wind Speed, County, Date]
# Index: []

# %%
weather_df.plot(kind = 'scatter', x = 'Latitude', y = 'Max Temperature (F)', title = 'City Latitude vs. Max Temperature (05/15/22)')
# Out:
# <AxesSubplot:title={'center':'City Latitude vs. Max Temperature (05/15/22)'}, xlabel='Latitude', ylabel='Max Temperature (F)'>

# %%
weather_df.plot(kind = 'scatter', x = 'Latitude', y = 'Humidity', title = 'City Latitude vs. Humidity (05/15/22)')
# Out:
# <AxesSubplot:title={'center':'City Latitude vs. Humidity (05/15/22)'}, xlabel='Latitude', ylabel='Humidity'>

# %%
weather_df.plot(kind = 'scatter', x = 'Latitude', y = 'Cloudiness', title = 'City Latitude vs. Cloudiness (05/15/22)')
# Out:
# <AxesSubplot:title={'center':'City Latitude vs. Cloudiness (05/15/22)'}, xlabel='Latitude', ylabel='Cloudiness'>

# %%
weather_df.plot(kind = 'scatter', x = 'Latitude', y = 'Wind Speed', title = 'City Latitude vs. Wind Speed (05/15/22)')
# Out:
# <AxesSubplot:title={'center':'City Latitude vs. Wind Speed (05/15/22)'}, xlabel='Latitude', ylabel='Wind Speed'>

# %%
northern_df = weather_df.loc[(weather_df['Latitude'] >= 0), :]
southern_df = weather_df.loc[(weather_df['Latitude'] <= 0), :]

# %%
#Northern Hemisphere - Temperature (F) vs. Latitude
x_values = northern_df['Latitude'].astype('float')
y_values = northern_df['Max Temperature (F)'].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept, 2))

plt.scatter(x_values, y_values)

plt.plot(x_values, regress_values, 'r-')
plt.annotate(line_eq, (0,-10), fontsize = 15, color = 'red')

plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

print(f'R squared: {rvalue**2}')

plt.show()
# Out:
# R squared: 0.6437082518856309

# %%
x_values = southern_df['Latitude'].astype('float')
y_values = southern_df['Max Temperature (F)'].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept, 2))

plt.scatter(x_values, y_values)

plt.plot(x_values, regress_values, 'r-')
plt.annotate(line_eq, (-50, 35), fontsize = 15, color = 'red')

plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

print(f'R squared: {rvalue**2}')

plt.show()
# Out:
# R squared: 0.6015945769348454

# %%
# Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = northern_df['Latitude'].astype('float')
y_values = northern_df['Humidity'].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept, 2))

plt.scatter(x_values, y_values)

plt.plot(x_values, regress_values, 'r-')
plt.annotate(line_eq, (45,4), fontsize = 15, color = 'red')

plt.xlabel('Latitude')
plt.ylabel('Humidity')

print(f'R squared: {rvalue**2}')

plt.show()
# Out:
# R squared: 0.0347110246491338

# %%
x_values = southern_df['Latitude'].astype('float')
y_values = southern_df['Humidity'].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept, 2))

plt.scatter(x_values, y_values)

plt.plot(x_values, regress_values, 'r-')
plt.annotate(line_eq, (-50, 20), fontsize = 15, color = 'red')

plt.xlabel('Latitude')
plt.ylabel('Humidity')

print(f'R squared: {rvalue**2}')

plt.show()
# Out:
# R squared: 0.029129632296144167

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = northern_df['Latitude'].astype('float')
y_values = northern_df['Cloudiness'].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept, 2))

plt.scatter(x_values, y_values)

plt.plot(x_values, regress_values, 'r-')
plt.annotate(line_eq, (45,4), fontsize = 15, color = 'red')

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

print(f'R squared: {rvalue**2}')

plt.show()
# Out:
# R squared: 0.009595975105198024

# %%
x_values = southern_df['Latitude'].astype('float')
y_values = southern_df['Cloudiness'].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept, 2))

plt.scatter(x_values, y_values)

plt.plot(x_values, regress_values, 'r-')
plt.annotate(line_eq, (-50, 20), fontsize = 15, color = 'red')

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

print(f'R squared: {rvalue**2}')

plt.show()
# Out:
# R squared: 0.012507958967306963

# %%
x_values = northern_df['Latitude'].astype('float')
y_values = northern_df['Wind Speed'].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept, 2))

plt.scatter(x_values, y_values)

plt.plot(x_values, regress_values, 'r-')
plt.annotate(line_eq, (45,12), fontsize = 15, color = 'red')

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

print(f'R squared: {rvalue**2}')

plt.show()
# Out:
# R squared: 0.010171853086092234

# %%
x_values = southern_df['Latitude'].astype('float')
y_values = southern_df['Wind Speed'].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept, 2))

plt.scatter(x_values, y_values)

plt.plot(x_values, regress_values, 'r-')
plt.annotate(line_eq, (-50, 10), fontsize = 15, color = 'red')

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

print(f'R squared: {rvalue**2}')

plt.show()
# Out:
# R squared: 0.02168459395937183
